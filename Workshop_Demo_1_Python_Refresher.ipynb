# %% [markdown]
# <a href="https://colab.research.google.com/github/mayanktiwari021-code/GCC-Sales/blob/main/Workshop_Demo_1_Python_Refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Python Basics: A 10-Minute Exercise
#
# This exercise will guide you through the very basics of Python: printing a message, using variables, and calling a simple function. Feel free to modify the code and run each cell to see how it works!
#
# ---
#
# #### Exercise 1: Hello World!
#
# This is the simplest way to get Python to do something: print a message to the console.
#
# **Instructions:**
# 1.  Click on the code block below.
# 2.  Run the cell by pressing `Shift + Enter` or by clicking the 'Play' button next to the cell.
# 3.  See the output 'Hello, Colab!' below the code block.
# 4.  **Challenge:** Change the message inside the quotes to something else, then run it again!

# %%
print("Hello, Colab!")
# Out:
# Hello, Colab!

# %% [markdown]
# ---
#
# #### Exercise 2: Using Variables
#
# Variables are like containers for storing information. You give them a name, and then you can use that name to refer to the stored value.
#
# **Instructions:**
# 1.  Run the code block below.
# 2.  Notice how the `name` variable stores the text 'Alice' and `age` stores the number `30`.
# 3.  The `print()` function then uses these variables to construct a sentence.
# 4.  **Challenge:** Change the values for `name` and `age`. Add a new variable (e.g., `city`) and include it in the `print()` statement. Run the cell to see your changes!

# %%
name = "Kumar"
age = 30

print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Kumar and I am 30 years old.

# %% [markdown]
# ---
#
# #### Exercise 3: Calling a Function
#
# Functions are blocks of organized, reusable code that perform a single, related action. They help make your code more modular and easier to manage.
#
# **Instructions:**
# 1.  First, run the code block below to define the function `greet_user`.
# 2.  Then, run the second code block which calls the `greet_user` function with the argument 'Bob'.
# 3.  Notice how the function takes 'Bob' and uses it to print a personalized greeting.
# 4.  **Challenge:** Modify the second code block to call `greet_user` with a different name. You can also try adding another parameter to the `greet_user` function (e.g., `greeting_message`) and modify both the function definition and its call to use it.

# %%
def greet_user(username):
    print(f"Hello, {username}! Welcome to Python.")

# %%
greet_user("Kumar")
# Out:
# Hello, Kumar! Welcome to Python.

# %%
greet_user("Sridhar")
# Out:
# Hello, Sridhar! Welcome to Python.
